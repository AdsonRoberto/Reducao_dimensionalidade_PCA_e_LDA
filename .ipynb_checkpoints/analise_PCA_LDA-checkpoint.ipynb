# %% [markdown]
# # importando bibliotecas

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import scipy

# %%
#Lendo os dados com pandas 
dados = pd.read_csv("winequality-red.csv")

#exibindo os cinco primeiros do dataset
dados.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# 3      9.8        6
# 4      9.4        5

# %%
# Adicionando nome ID na primeira coluna 
dados.rename_axis("ID", axis = 'columns', inplace = True)
dados.head()
# Out:
# ID  fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0             7.4              0.70         0.00             1.9      0.076
# 1             7.8              0.88         0.00             2.6      0.098
# 2             7.8              0.76         0.04             2.3      0.092
# 3            11.2              0.28         0.56             1.9      0.075
# 4             7.4              0.70         0.00             1.9      0.076
#
# ID  free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                  11.0                  34.0   0.9978  3.51       0.56
# 1                  25.0                  67.0   0.9968  3.20       0.68
# 2                  15.0                  54.0   0.9970  3.26       0.65
# 3                  17.0                  60.0   0.9980  3.16       0.58
# 4                  11.0                  34.0   0.9978  3.51       0.56
#
# ID  alcohol  quality
# 0       9.4        5
# 1       9.8        5
# 2       9.8        5
# 3       9.8        6
# 4       9.4        5

# %%
# criando uma matriz X com os valores do data frame
X = dados.iloc[:,0:-1].values # exceto a coluna dos IDs e da classe

# %%
from sklearn.preprocessing import StandardScaler
X = StandardScaler().fit_transform(X)

# %%
#Vamos converter os recursos normalizados em um formato tabular com a ajuda do DataFrame
feat_cols = ['feature'+str(i) for i in range(X.shape[1])]
normalised_dados = pd.DataFrame(X,columns=feat_cols)
normalised_dados.tail()
# Out:
#       feature0  feature1  feature2  feature3  feature4  feature5  feature6  \
# 1594 -1.217796  0.403229 -0.980669 -0.382271  0.053845  1.542054 -0.075043
# 1595 -1.390155  0.123905 -0.877968 -0.240375 -0.541259  2.211469  0.137820
# 1596 -1.160343 -0.099554 -0.723916 -0.169427 -0.243707  1.255161 -0.196679
# 1597 -1.390155  0.654620 -0.775267 -0.382271 -0.264960  1.542054 -0.075043
# 1598 -1.332702 -1.216849  1.021999  0.752894 -0.434990  0.203223 -0.135861
#
#       feature7  feature8  feature9  feature10
# 1594 -0.978765  0.899886 -0.461180   0.072294
# 1595 -0.862162  1.353436  0.601055   0.729364
# 1596 -0.533554  0.705508  0.542042   0.541630
# 1597 -0.676657  1.677400  0.305990  -0.209308
# 1598 -0.666057  0.511130  0.010924   0.541630

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=2)
pca_dados = pca.fit_transform(normalised_dados)

# %%
pca_df = pd.DataFrame(data = pca_dados, columns = ['principal componente 1', 'principal componente 2'])
finalDf = pd.concat([pca_df, dados[['quality']]], axis = 1)

# %%
finalDf
# Out:
#       principal componente 1  principal componente 2  quality
# 0                  -1.619530                0.450950        5
# 1                  -0.799170                1.856553        5
# 2                  -0.748479                0.882039        5
# 3                   2.357673               -0.269976        6
# 4                  -1.619530                0.450950        5
# ...                      ...                     ...      ...
# 1594               -2.150500                0.814286        5
# 1595               -2.214496                0.893101        6
# 1596               -1.456129                0.311746        6
# 1597               -2.270518                0.979791        5
# 1598               -0.426975               -0.536690        6
#
# [1599 rows x 3 columns]

# %%
import matplotlib.pyplot as plt

fig = plt.figure(figsize = (8,8))
ax = fig.add_subplot(1,1,1) 
ax.set_xlabel('Principal Component 1', fontsize = 15)
ax.set_ylabel('Principal Component 2', fontsize = 15)
ax.set_title('2 component PCA', fontsize = 20)
targets = [3, 8, 4, 7, 6, 5]
colors = ['m', 'c', 'k', 'r', 'g', 'b']
for target, color in zip(targets,colors):
    indicesToKeep = finalDf['quality'] == target
    ax.scatter(finalDf.loc[indicesToKeep, 'principal componente 1'], 
               finalDf.loc[indicesToKeep, 'principal componente 2'], 
               c = color, s = 50)
ax.legend(targets)
ax.grid()

# %%
pca_dados = pca.fit(normalised_dados)
cov = pca_dados.get_covariance()

# %%
from scipy import linalg as LA

values, vectors = LA.eig(cov)

# %%
values = np.around(values, 4)

# %%
print('Matriz de covariância: ')
covariance_pd = pd.DataFrame(cov)
display(covariance_pd)
# Out:
# Matriz de covariância:
#           0         1         2         3         4         5         6   \
# 0   1.263152 -0.322840  0.573992  0.136243  0.232412 -0.114778 -0.051359
# 1  -0.322840  0.898459 -0.322244  0.009519 -0.071994  0.199325  0.184012
# 2   0.573992 -0.322244  1.217190  0.112913  0.211410 -0.139292 -0.082528
# 3   0.136243  0.009519  0.112913  0.809801  0.126435  0.163582  0.204062
# 4   0.232412 -0.071994  0.211410  0.126435  0.801753  0.077317  0.118665
# 5  -0.114778  0.199325 -0.139292  0.163582  0.077317  1.000554  0.367258
# 6  -0.051359  0.184012 -0.082528  0.204062  0.118665  0.367258  1.075204
# 7   0.438804 -0.148754  0.401883  0.221011  0.248145  0.116649  0.190689
# 8  -0.523804  0.257275 -0.496710 -0.153820 -0.225546  0.042989 -0.020365
# 9   0.294887 -0.154267  0.281642  0.073584  0.118617 -0.045758 -0.013052
# 10 -0.081122 -0.068246 -0.053901 -0.173001 -0.130764 -0.240477 -0.284229
#
#           7         8         9         10
# 0   0.438804 -0.523804  0.294887 -0.081122
# 1  -0.148754  0.257275 -0.154267 -0.068246
# 2   0.401883 -0.496710  0.281642 -0.053901
# 3   0.221011 -0.153820  0.073584 -0.173001
# 4   0.248145 -0.225546  0.118617 -0.130764
# 5   0.116649  0.042989 -0.045758 -0.240477
# 6   0.190689 -0.020365 -0.013052 -0.284229
# 7   1.114073 -0.420484  0.222950 -0.222995
# 8  -0.420484  1.132946 -0.259897  0.117724
# 9   0.222950 -0.259897  0.809876 -0.048713
# 10 -0.222995  0.117724 -0.048713  0.883874

# %%
print('Autovalores: ')
values_pd = pd.DataFrame(values)
display(values_pd)
# Out:
# Autovalores:
#                  0
# 0   0.6643+0.0000j
# 1   3.1011+0.0000j
# 2   1.9271+0.0000j
# 3   0.6643+0.0000j
# 4   0.6643+0.0000j
# 5   0.6643+0.0000j
# 6   0.6643+0.0000j
# 7   0.6643+0.0000j
# 8   0.6643+0.0000j
# 9   0.6643+0.0000j
# 10  0.6643+0.0000j

# %%
print('Autovetores: ')
vectors_pd = pd.DataFrame(vectors)
display(vectors_pd)
# Out:
# Autovetores:
#           0         1         2         3         4         5         6   \
# 0  -0.865078 -0.489314  0.110503 -0.138145  0.045196  0.103141 -0.210825
# 1  -0.170069  0.238584 -0.274930 -0.629311 -0.228022 -0.340530 -0.237562
# 2   0.281633 -0.463632  0.151791  0.181914 -0.594535 -0.193643  0.082491
# 3   0.047888 -0.146107 -0.272080 -0.570020 -0.597840  0.598098  0.334656
# 4   0.101141 -0.212247 -0.148052  0.047696  0.148590  0.130717 -0.713625
# 5  -0.086053  0.036158 -0.513567  0.280255  0.158964 -0.494440 -0.327775
# 6  -0.059410 -0.023575 -0.569487  0.265380 -0.117105  0.229806  0.219906
# 7   0.193787 -0.395353 -0.233575  0.046263  0.216325 -0.006833  0.015415
# 8  -0.248897  0.438520 -0.006711  0.262780 -0.295912  0.402254 -0.176938
# 9   0.142201 -0.242921  0.037554 -0.001817  0.126597 -0.022866 -0.087105
# 10 -0.014718  0.113232  0.386181 -0.066539 -0.153720 -0.037902 -0.275918
#
#           7         8         9         10
# 0  -0.234786 -0.260519  0.067983  0.319765
# 1  -0.504217  0.527911 -0.089661  0.302080
# 2  -0.048215  0.297510 -0.009701 -0.022136
# 3   0.592819 -0.399022 -0.006389 -0.219707
# 4   0.121704  0.405219 -0.047309  0.379648
# 5   0.049064 -0.284235 -0.096691  0.176268
# 6  -0.106986  0.051080 -0.359517  0.126270
# 7  -0.458300 -0.190473  0.356097 -0.035218
# 8  -0.231098 -0.270145  0.141032 -0.164986
# 9  -0.126002  0.034693 -0.687710 -0.467914
# 10 -0.169985 -0.218281 -0.476156  0.564965

# %%
explained_variance = pca_dados.explained_variance_
explained_variance
# Out:
# array([3.10107182, 1.92711489])

# %%
n_components = 2
pca_test = PCA(n_components)
pca_dados_test = pca_test.fit_transform(normalised_dados)

# %%
#No exemplo abaixo, nosso conjunto de dados contém 10 recursos, mas selecionamos apenas os 2 primeiros componente e eles explicam 45% da variância total.

total_var = pca_test.explained_variance_ratio_.sum() * 100

print(total_var)
# Out:
# 45.68220118429407

# %%
import cv2

setosa = cv2.cvtColor(cv2.imread('setosa.jpg'), cv2.COLOR_BGR2RGB)
versicolor = cv2.cvtColor(cv2.imread('versicolor.jpg'), cv2.COLOR_BGR2RGB)
virginica = cv2.cvtColor(cv2.imread('virginica.jpg'), cv2.COLOR_BGR2RGB)

# Plotando as imagens 
fig = plt.figure (figsize = (15, 7.2)) 
fig.add_subplot (131) 
plt.title ("Setosa") 
plt.imshow (setosa)
fig.add_subplot (132) 
plt.title ("Versicolor") 
plt.imshow (versicolor)
fig.add_subplot (133) 
plt.title ("Virginica") 
plt.imshow (virginica)
plt.show ()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [30], in <cell line: 1>()
# ----> 1 import cv2
#       3 setosa = cv2.cvtColor(cv2.imread('setosa.jpg'), cv2.COLOR_BGR2RGB)
#       4 versicolor = cv2.cvtColor(cv2.imread('versicolor.jpg'), cv2.COLOR_BGR2RGB)
#
# ModuleNotFoundError: No module named 'cv2'
